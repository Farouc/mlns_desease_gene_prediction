# %% [markdown]
# # Analysis Notebook
#
# Use this notebook to inspect prediction files, metrics, and interpretability outputs from `experiments/results/<run_id>`.

# %%
from pathlib import Path
import pandas as pd

run_dir = Path('../experiments/results').resolve()
print('Available runs:')
for p in sorted(run_dir.glob('*')):
    if p.is_dir():
        print('-', p.name)
